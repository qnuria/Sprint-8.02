# %% [markdown]
# Nivel 1
#
# Ejercicio 1
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(amount)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_theme(style="darkgrid", context="notebook")
# sns.histplot(data=dataset,
#               x="amount",
#               stat='density',
#               shrink=0.9)
# plt.title('Distribución de la cantidad de las transacciones')
# plt.xlabel("Importe transacción $")
# plt.ylabel("Densidad")
# plt.show()
# '''

# %% [markdown]
# Ejercicio 2
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(weight, amount, num)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import matplotlib.pyplot as plt
# import seaborn as sns
# dataset['weight'] = dataset['weight'].astype(float)
# sns.set_theme(style="darkgrid", context="notebook")
# sns.scatterplot(x=dataset["weight"],
#             y=dataset["amount"],
#             hue= dataset["num"])
# plt.title("Relación entre peso y importes")
# plt.xlabel("Peso")
# plt.ylabel("Importes transacción")
# plt.show()
# '''

# %% [markdown]
# Ejercicio 3
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(country)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_theme(style="darkgrid", context="notebook")
# sns.catplot(data=dataset,
#             x="country",
#             kind="count",
#             errorbar=None)
# plt.title("Cantidad usuarios por país")
# plt.xlabel("País")
#
# plt.show()
# '''

# %% [markdown]
# Ejercicio 4
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(country, amount)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import matplotlib.pyplot as plt
# import seaborn as sns
#
#
# sns.set_theme(style="darkgrid", context="notebook")
# sns.catplot(x="country",
#             y="amount",
#             data=dataset,
#             kind="box",
#             aspect=3)
# plt.title("Importes transacciones por paises")
# plt.xlabel("Países")
# plt.ylabel("Importes transacción")
# plt.show()
# '''

# %% [markdown]
# Ejercicio 5
#
# No puedo representar este grafico porque Power BI no soporta plotly.express

# %% [markdown]
# Ejercicio 6
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(country, declined, amount)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
# sns.set_theme(style="darkgrid", context="notebook")
# sns.catplot(
#     data=dataset,
#     x="country",
#     y="amount",
#     hue="declined",
#     kind="bar",
#     errorbar=None,
#     aspect=3
# )
#
# # Agregar título y etiquetas
# plt.title("Suma de importes de transacciones por país - declinadas y no declinadas")
# plt.xlabel("País")
# plt.ylabel("Suma de importes de transacciones")
# plt.xticks(rotation=45)
#
#
# plt.show()
# '''

# %% [markdown]
# Ejercicio 7
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(price, weight)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import matplotlib.pyplot as plt
# import seaborn as sns
# dataset['price'] = dataset['price'].str.replace('$', '').str.strip().astype(float)
# cols_to_plot=["weight","price"]
# sns.pairplot(dataset[cols_to_plot],
#              diag_kind="hist",
#              diag_kws={"color":"red", "bins":12} ,
#
#              kind="reg",
#              plot_kws={'line_kws':{"color":"red"}},
#
#
#              )
#
# plt.show()
# '''

# %% [markdown]
# Nivel 2
#
# Ejercicio 1
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(amount, lat, longitud)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import seaborn as sns
# import matplotlib.pyplot as plt
# columnsheatmap=["amount", "lat", "longitud"]
#
# dataset=dataset[columnsheatmap]
# corr_matrix=dataset.corr()
# print(corr_matrix)
# sns.heatmap(corr_matrix,
#              annot=True,
#              cmap="YlGnBu",
#              vmax=1,
#              vmin=-1)
# plt.title("Gráfico de calor")
# plt.show()
# '''
#
# ![image-2.png](attachment:image-2.png)
#
# '''
# # dataset = pandas.DataFrame(weight, price)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
# import seaborn as sns
# import matplotlib.pyplot as plt
# dataset['price'] = dataset['price'].str.replace('$', '').str.strip().astype(float)
# columnsheatmap2=["weight", "price"]
#
# dataset=dataset[columnsheatmap2]
# corr_matrix2=dataset.corr()
# print(corr_matrix2)
# sns.heatmap(corr_matrix2,
#              annot=True,
#              cmap="YlGnBu",
#              vmax=1,
#              vmin=-1)
# plt.title("Gráfico de calor")
# plt.show()
# '''

# %% [markdown]
# Ejercicio 2
#
# ![image.png](attachment:image.png)
#
# '''
# # dataset = pandas.DataFrame(amount, num, declined)
# # dataset = dataset.drop_duplicates()
#
# # Pegue o escriba aquí el código de script:
#
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.jointplot(data=dataset,
#                  x="amount",
#                   y="num",
#                   hue= "declined",
#                   height=8,
#                   ratio=5,
#                   space=0.5,
#                   s=100,
#                   )
# plt.title("Transacciones declinadas/definitivas segun nº de productos comprados e importe")
# plt.xlabel("Importe transacción")
# plt.ylabel("Nº productos comprados")
# plt.show()
# '''
